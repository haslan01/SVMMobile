# %%
# Importing required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR  # Import the SVR model from sklearn
from sklearn.metrics import mean_absolute_error

# %%
# Importing data
data = pd.read_csv('Dataset.csv')
predictors = ['Lomba', 'Organisasi', 'IPS_1', 'IPS_2', 'IPS_3', 'Absensi_smstr_1', 'Absensi_smstr_2', 'Absensi_smstr_3', 'SKS_smstr_1', 'SKS_smstr_2', 'SKS_smstr_3']
label = 'Prestasi'

data
# Out:
#      Lomba  Organisasi  IPS_1  IPS_2  IPS_3  Absensi_smstr_1  Absensi_smstr_2
# 0        0           1    2.8    3.1    2.9             16.0               14  \
# 1        1           2    3.2    3.4    3.0             15.0               13
# 2        0           1    2.9    3.0    2.7             18.0               15
# 3        1           1    3.0    3.2    3.1             17.0               16
# 4        0           2    3.1    3.3    3.2             19.0               18
# ..     ...         ...    ...    ...    ...              ...              ...
# 235      1           2    3.5    3.7    3.6             14.0               15
# 236      1           1    3.2    3.4    3.3             16.0               18
# 237      0           2    2.7    3.0    2.9             17.0               16
# 238      0           1    3.0    3.2    3.1             15.0               14
# 239      1           2    3.3    3.6    3.4             18.0               17
#
#      Absensi_smstr_3  SKS_smstr_1  SKS_smstr_2  SKS_smstr_3        Prestasi
# 0                 13           19           20           22       Rendah
# 1                 14           18           20           21   Tidak Rendah
# 2                 12           20           19           22       Rendah
# 3                 14           19           21           23   Tidak Rendah
# 4                 15           21           22           23   Tidak Rendah
# ..               ...          ...          ...          ...             ...
# 235               14           17           19           20   Tidak Rendah
# 236               17           19           20           21   Tidak Rendah
# 237               15           18           19           20       Rendah
# 238               14           19           20           22   Tidak Rendah
# 239               16           20           21           23   Tidak Rendah
#
# [240 rows x 12 columns]

# %%
# Encoding categorical features
le = dict()
for column in data.columns:
    if data[column].dtype == np.object:
        le[column] = LabelEncoder()
        data[column] = le[column].fit_transform(data[column])
data
# Out:
# C:\Users\aslan\AppData\Local\Temp\ipykernel_9856\1491061146.py:4: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   if data[column].dtype == np.object:
#      Lomba  Organisasi  IPS_1  IPS_2  IPS_3  Absensi_smstr_1  Absensi_smstr_2
# 0        0           1    2.8    3.1    2.9             16.0               14  \
# 1        1           2    3.2    3.4    3.0             15.0               13
# 2        0           1    2.9    3.0    2.7             18.0               15
# 3        1           1    3.0    3.2    3.1             17.0               16
# 4        0           2    3.1    3.3    3.2             19.0               18
# ..     ...         ...    ...    ...    ...              ...              ...
# 235      1           2    3.5    3.7    3.6             14.0               15
# 236      1           1    3.2    3.4    3.3             16.0               18
# 237      0           2    2.7    3.0    2.9             17.0               16
# 238      0           1    3.0    3.2    3.1             15.0               14
# 239      1           2    3.3    3.6    3.4             18.0               17
#
#      Absensi_smstr_3  SKS_smstr_1  SKS_smstr_2  SKS_smstr_3  Prestasi
# 0                 13           19           20           22         0
# 1                 14           18           20           21         1
# 2                 12           20           19           22         0
# 3                 14           19           21           23         1
# 4                 15           21           22           23         1
# ..               ...          ...          ...          ...       ...
# 235               14           17           19           20         1
# 236               17           19           20           21         1
# 237               15           18           19           20         0
# 238               14           19           20           22         1
# 239               16           20           21           23         1
#
# [240 rows x 12 columns]

# %%
# Variabel Independen
X = data.drop([label], axis=1)

data
# Out:
#      Lomba  Organisasi  IPS_1  IPS_2  IPS_3  Absensi_smstr_1  Absensi_smstr_2
# 0        0           1    2.8    3.1    2.9             16.0               14  \
# 1        1           2    3.2    3.4    3.0             15.0               13
# 2        0           1    2.9    3.0    2.7             18.0               15
# 3        1           1    3.0    3.2    3.1             17.0               16
# 4        0           2    3.1    3.3    3.2             19.0               18
# ..     ...         ...    ...    ...    ...              ...              ...
# 235      1           2    3.5    3.7    3.6             14.0               15
# 236      1           1    3.2    3.4    3.3             16.0               18
# 237      0           2    2.7    3.0    2.9             17.0               16
# 238      0           1    3.0    3.2    3.1             15.0               14
# 239      1           2    3.3    3.6    3.4             18.0               17
#
#      Absensi_smstr_3  SKS_smstr_1  SKS_smstr_2  SKS_smstr_3  Prestasi
# 0                 13           19           20           22         0
# 1                 14           18           20           21         1
# 2                 12           20           19           22         0
# 3                 14           19           21           23         1
# 4                 15           21           22           23         1
# ..               ...          ...          ...          ...       ...
# 235               14           17           19           20         1
# 236               17           19           20           21         1
# 237               15           18           19           20         0
# 238               14           19           20           22         1
# 239               16           20           21           23         1
#
# [240 rows x 12 columns]

# %%
# Variabel Dependen
y = data[label]

data
# Out:
#      Lomba  Organisasi  IPS_1  IPS_2  IPS_3  Absensi_smstr_1  Absensi_smstr_2
# 0        0           1    2.8    3.1    2.9             16.0               14  \
# 1        1           2    3.2    3.4    3.0             15.0               13
# 2        0           1    2.9    3.0    2.7             18.0               15
# 3        1           1    3.0    3.2    3.1             17.0               16
# 4        0           2    3.1    3.3    3.2             19.0               18
# ..     ...         ...    ...    ...    ...              ...              ...
# 235      1           2    3.5    3.7    3.6             14.0               15
# 236      1           1    3.2    3.4    3.3             16.0               18
# 237      0           2    2.7    3.0    2.9             17.0               16
# 238      0           1    3.0    3.2    3.1             15.0               14
# 239      1           2    3.3    3.6    3.4             18.0               17
#
#      Absensi_smstr_3  SKS_smstr_1  SKS_smstr_2  SKS_smstr_3  Prestasi
# 0                 13           19           20           22         0
# 1                 14           18           20           21         1
# 2                 12           20           19           22         0
# 3                 14           19           21           23         1
# 4                 15           21           22           23         1
# ..               ...          ...          ...          ...       ...
# 235               14           17           19           20         1
# 236               17           19           20           21         1
# 237               15           18           19           20         0
# 238               14           19           20           22         1
# 239               16           20           21           23         1
#
# [240 rows x 12 columns]

# %%
# Data Testing and Training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
# Create and train the SVR model
regressor = SVR(kernel='linear')  # Use 'linear' kernel for simplicity
regressor.fit(X_train, y_train)
# Out:
# SVR(kernel='linear')

# %%
# Prediction
y_pred = regressor.predict(X_test)

# %%
# Perhitungan Akurasi dengan menggunakan Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error:', mae)
accuracy = 100 - (mae * 100)
print('Nilai akurasi :', round(accuracy, 2),'%')
# Out:
# Mean Absolute Error: 0.12438961237465967
# Nilai akurasi : 87.56 %

# %%
# Nilai Koefisien Determinasi Data Testing
from sklearn.metrics import r2_score
koefisien = r2_score(y_test, y_pred)
print('Nilai Koefisien Determinasi Data Testing :', round(koefisien, 2))
# Out:
# Nilai Koefisien Determinasi Data Testing : 0.89

# %%
# Perbandingan nilai aktual dan prediksi
import matplotlib.pyplot as plt
plt.plot(y_test, label="Data Asli")
plt.plot(y_pred, label="Data prediksi")
plt.ylabel('Data Prestasi')
plt.xlabel('data ke-i')
plt.legend()
plt.show()

# %%
# Save the model to a file
pickle.dump(regressor, open('modelsvm.pkl', 'wb'))

# %%
# Load the model from file and make a prediction
model = pickle.load(open('modelsvm.pkl', 'rb'))
print(model.predict([[0, 1, 2.8, 3.1, 2.9, 16, 14, 13, 19, 20, 22]]))
# Out:
# [0.31772136]
# C:\Users\aslan\anaconda3\envs\aslan\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
